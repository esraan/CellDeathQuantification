# %%
import numpy as np
import pandas as pd
from scipy import io
import matplotlib.pyplot as plt

# %%
mat_file = io.loadmat('ExampleFiles/20160828_10AsgCx43_FB_xy01.mat')

# %%
mat_file = io.loadmat('ExampleFiles/20160828_10AsgCx43_FB_xy05.mat')

# %%
mat_file = io.loadmat('ExampleFiles/20160828_10AsgCx43_FB_xy13.mat')

# %%
for key in ['CentData_X', 'CentData_Y', 'MeanThruTimeSorted']:
    plt.hist(mat_file[key])
    plt.show()

# %%
plt.scatter(mat_file['CentData_X'], mat_file['CentData_Y'])
plt.show()

# %%
times = np.zeros((len(mat_file['MeanThruTimeSorted'])+1, 1))
times[0], times[1:] = 0, mat_file['MeanThruTimeSorted'].copy()
normalized_times = times/times.max()
plt.scatter(mat_file['Centroids2'][:, 0], mat_file['Centroids2'][:, 1], c=normalized_times)
plt.show()

# %%
def mat_to_csv(mat_path):
    mat_file = io.loadmat(mat_path)
    df = {
        'cell_x': mat_file['Centroids2'][:, 0],
        'cell_y': mat_file['Centroids2'][:, 1],
        'death_time': mat_file['MeanThruTimeSorted']
    }
    df = pd.DataFrame(df)
    return df
mat_file
